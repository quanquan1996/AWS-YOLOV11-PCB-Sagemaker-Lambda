# %%
# %pip uninstall -y sagemaker
# %pip uninstall -y ultralytics
# %pip uninstall -y datasets
# %pip install sagemaker
# %pip install ultralytics
# %pip install datasets
# Out:
# Found existing installation: sagemaker 2.232.0
# Uninstalling sagemaker-2.232.0:
#   Successfully uninstalled sagemaker-2.232.0
# Note: you may need to restart the kernel to use updated packages.
# Found existing installation: ultralytics 8.2.100
# Uninstalling ultralytics-8.2.100:
#   Successfully uninstalled ultralytics-8.2.100
# Note: you may need to restart the kernel to use updated packages.
# Found existing installation: datasets 2.18.0
# Uninstalling datasets-2.18.0:
#   Successfully uninstalled datasets-2.18.0
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.4 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 977.1/977.1 kB 6.4 MB/s eta 0:00:00-:--:--
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import Dataset
from ultralytics import YOLO

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fqm5Enl2aSi9tTuX0yyV")
project = rf.workspace("qpj").project("pcb_defect-1xgzf-1ibgb")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to PCB_defect-1 in yolov11:: 100%|██████████| 3618/3618 [00:00<00:00, 3839.83it/s]

# %%
from IPython.display import display, Image

# %%
# %ls
# Out:
# lost+found/    PCB_defect-1/  Untitled.ipynb      yolov8s.pt
# pcb-defect-1/  runs/          yolov11Train.ipynb  yolov8Train.ipynb

# %%
# 放弃，国内下载不下来 https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt，手动下载放目录
# !yolo task=detect mode=train model=/home/ec2-user/SageMaker/yolo11m.pt data=/home/ec2-user/SageMaker/PCB_defect-1/data.yaml epochs=150 imgsz=800 plots=True
# Out:
# Ultralytics 8.3.100 🚀 Python-3.10.14 torch-2.2.2 CUDA:0 (Tesla T4, 14918MiB)
# ...
